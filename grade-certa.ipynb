# %%
import meep as mp
import numpy as np
from meep.materials import Au
from matplotlib import pyplot as plt

def grating_simulation(period, nslits, t, w):
    resolution = 50         # pixels/μm                                                                                                                   
    
    dpml = 1.0              # PML thickness                                                                                                               
    dsub = 2.0              # substrate thickness                                                                                                         
    dpad = 2.0              # padding between grating and PML                                                                                             
    gp = period                # grating periodicity                                                                                                         
    gh = t                # grating height                                                                                                              
    gdc = 1.0               # grating duty cycle
    w = w
    
    num_cells = nslits
    gdc_list = [gdc for _ in range(num_cells)]
    
    wvl_min = 0.4
    wvl_max = 0.85
    fmin = 1 / wvl_max
    fmax = 1 / wvl_min
    fcen = 0.5 * (fmax + fmin)
    df = fmax - fmin
    nfreq = 200
    
    k_point = mp.Vector3()
    
    glass = mp.Medium(index=2)
    
    pml_layers = [mp.PML(thickness=dpml)]
    
    symmetries=[mp.Mirror(mp.Y)]
    
    sx = dpml+dsub+gh+dpad+dpml
    sy = dpml+num_cells*gp+dpml
    cell_size = mp.Vector3(sx,sy)
    
    src_pt = mp.Vector3(-0.5*sx+dpml+0.5*dpad)
    sources = [mp.Source(mp.GaussianSource(fcen, fwidth=df),
                         component=mp.Ey,
                         center=src_pt,
                         size=mp.Vector3(y=sy-2*dpml))]
    
    geometry = [mp.Block(material=glass,
                         size=mp.Vector3(dpml+dsub,mp.inf,mp.inf),
                         center=mp.Vector3(-0.5*sx+0.5*(dpml+dsub)))]
    
    sim = mp.Simulation(resolution=resolution,
                        cell_size=cell_size,
                        boundary_layers=pml_layers,
                        geometry=geometry,
                        k_point=k_point,
                        sources=sources,
                        symmetries=symmetries)
    
    incident_pt = mp.Vector3(0.5*sx-dpml-0.5*dpad)
    incident_region = mp.FluxRegion(center=incident_pt, size=mp.Vector3(y=sy-2*dpml))
    incident_flux_monitor = sim.add_flux(fcen,df,nfreq,incident_region)
    
    sim.run(until_after_sources=100)
    
    incident_flux_data = sim.get_flux_data(incident_flux_monitor)
    incident_flux = mp.get_fluxes(incident_flux_monitor)
    
    
    sim.reset_meep()
    
    for j in range(num_cells):
      geometry.append(mp.Block(material=Au,
                               size=mp.Vector3(gh,gdc_list[j]*gp-w,mp.inf),
                               center=mp.Vector3(-0.5*sx+dpml+dsub+0.5*gh,-0.5*sy+dpml+(j+0.5)*gp)))
    
    sim = mp.Simulation(resolution=resolution,
                        cell_size=cell_size,
                        boundary_layers=pml_layers,
                        geometry=geometry,
                        k_point=k_point,
                        sources=sources,
                        symmetries=symmetries)
    
    transmission_pt = mp.Vector3(0.5*sx-dpml-0.5*dpad)
    transmission_region = mp.FluxRegion(center=transmission_pt, size=mp.Vector3(y=sy-2*dpml))
    transmission_flux_monitor = sim.add_flux(fcen,df,nfreq,transmission_region)
    
    sim.run(until_after_sources=100)
    
    transmitted_flux = mp.get_fluxes(transmission_flux_monitor)
    T = abs(np.divide(transmitted_flux, incident_flux))
    
    freqs = mp.get_flux_freqs(transmission_flux_monitor)
    wvls = np.divide(1000, freqs)
    
    per = gp*1000
    plt.plot(wvls, T/T.max(), label='p = %d nm' % per)
    
    # Adicione um título ao gráfico
    plt.title('')
    
    # Adicione rótulos aos eixos
    plt.ylabel('Transmission (a.u.)')
    plt.xlabel('Wavelength (nm)')
    
    # Adicione uma legenda
    plt.legend()
    
    plt.savefig('p=%d'%per)

    plt.close()
    
    with open("p=%dnm.txt"%per, "w") as file:
        # Passo 3: Iterar sobre os elementos dos arrays e escrever no formato desejado
        for x, y in zip(wvls, T/T.max()):
            file.write(f"{x} {y}\n")  # Escreve no formato "x y" e adiciona uma nova linha
    return

# %%
grating_simulation(0.3, 66, 0.17, 0.06)
grating_simulation(0.4, 50, 0.17, 0.06)
grating_simulation(0.5, 40, 0.17, 0.06)
grating_simulation(0.7, 29, 0.17, 0.06)
grating_simulation(0.9, 23, 0.17, 0.06)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000404119 s
# Working in 2D dimensions.
# Computational cell is 6.18 x 21.8 x 0 with resolution 50
#      block, center = (-1.585,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (4,4,4)
# time for set_epsilon = 0.181029 s
# -----------
# Meep progress: 57.52/107.55555534362793 = 53.5% done in 4.0s, 3.5s to go
# on time step 5752 (time=57.52), 0.000695486 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 107.56 (10756 timesteps)
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000518084 s
# Working in 2D dimensions.
# Computational cell is 6.18 x 21.8 x 0 with resolution 50
#      block, center = (-1.585,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (4,4,4)
#      block, center = (4.16334e-17,-9.75,0)
#           size (0.17,0.24,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-9.45,0)
#           size (0.17,0.24,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-9.15,0)
#           size (0.17,0.24,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-8.85,0)
#           size (0.17,0.24,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-8.55,0)
#           size (0.17,0.24,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-8.25,0)
#           size (0.17,0.24,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-7.95,0)
#           size (0.17,0.24,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-7.65,0)
#           size (0.17,0.24,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-7.35,0)
#           size (0.17,0.24,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 57 objects not shown)...
# time for set_epsilon = 0.277473 s
# lorentzian susceptibility: frequency=10.7433, gamma=1.78571
# lorentzian susceptibility: frequency=3.47141, gamma=2.01155
# lorentzian susceptibility: frequency=2.39466, gamma=0.701702
# lorentzian susceptibility: frequency=0.66944, gamma=0.278261
# lorentzian susceptibility: frequency=0.33472, gamma=0.19438
# drude susceptibility: frequency=1e-10, gamma=0.0427474
# -----------
# Meep progress: 6.3500000000000005/107.55555534362793 = 5.9% done in 4.0s, 63.8s to go
# on time step 635 (time=6.35), 0.00630824 s/step
# Meep progress: 12.74/107.55555534362793 = 11.8% done in 8.0s, 59.6s to go
# on time step 1274 (time=12.74), 0.00626064 s/step
# Meep progress: 19.09/107.55555534362793 = 17.7% done in 12.0s, 55.7s to go
# on time step 1909 (time=19.09), 0.00630219 s/step
# Meep progress: 25.25/107.55555534362793 = 23.5% done in 16.0s, 52.2s to go
# on time step 2525 (time=25.25), 0.00650053 s/step
# Meep progress: 30.11/107.55555534362793 = 28.0% done in 20.0s, 51.5s to go
# on time step 3011 (time=30.11), 0.00823056 s/step
# Meep progress: 35.15/107.55555534362793 = 32.7% done in 24.0s, 49.5s to go
# on time step 3515 (time=35.15), 0.00795604 s/step
# Meep progress: 38.84/107.55555534362793 = 36.1% done in 28.0s, 49.6s to go
# on time step 3884 (time=38.84), 0.0108509 s/step
# Meep progress: 43.67/107.55555534362793 = 40.6% done in 32.0s, 46.9s to go
# on time step 4367 (time=43.67), 0.00828599 s/step
# Meep progress: 49.09/107.55555534362793 = 45.6% done in 36.0s, 42.9s to go
# on time step 4909 (time=49.09), 0.00738886 s/step
# Meep progress: 55.18/107.55555534362793 = 51.3% done in 40.0s, 38.0s to go
# on time step 5519 (time=55.19), 0.00656811 s/step
# Meep progress: 60.47/107.55555534362793 = 56.2% done in 44.0s, 34.3s to go
# on time step 6048 (time=60.48), 0.00756873 s/step
# Meep progress: 63.440000000000005/107.55555534362793 = 59.0% done in 48.1s, 33.4s to go
# on time step 6344 (time=63.44), 0.0135485 s/step
# Meep progress: 64.84/107.55555534362793 = 60.3% done in 52.1s, 34.3s to go
# on time step 6484 (time=64.84), 0.0286777 s/step
# Meep progress: 66.26/107.55555534362793 = 61.6% done in 56.1s, 35.0s to go
# on time step 6626 (time=66.26), 0.0283062 s/step
# Meep progress: 67.61/107.55555534362793 = 62.9% done in 60.1s, 35.5s to go
# on time step 6761 (time=67.61), 0.0297245 s/step
# Meep progress: 69.01/107.55555534362793 = 64.2% done in 64.1s, 35.8s to go
# on time step 6901 (time=69.01), 0.0286842 s/step
# Meep progress: 71.64/107.55555534362793 = 66.6% done in 68.1s, 34.2s to go
# on time step 7164 (time=71.64), 0.0152125 s/step
# Meep progress: 77.21000000000001/107.55555534362793 = 71.8% done in 72.1s, 28.4s to go
# on time step 7721 (time=77.21), 0.00718997 s/step
# Meep progress: 83.60000000000001/107.55555534362793 = 77.7% done in 76.1s, 21.8s to go
# on time step 8360 (time=83.6), 0.00626185 s/step
# Meep progress: 89.9/107.55555534362793 = 83.6% done in 80.1s, 15.7s to go
# on time step 8991 (time=89.91), 0.00634911 s/step
# Meep progress: 96.24000000000001/107.55555534362793 = 89.5% done in 84.1s, 9.9s to go
# on time step 9625 (time=96.25), 0.00630955 s/step
# Meep progress: 102.58/107.55555534362793 = 95.4% done in 88.1s, 4.3s to go
# on time step 10259 (time=102.59), 0.00631559 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 107.56 (10756 timesteps)
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000580072 s
# Working in 2D dimensions.
# Computational cell is 6.18 x 22 x 0 with resolution 50
#      block, center = (-1.585,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (4,4,4)
# time for set_epsilon = 0.184662 s
# -----------
# Meep progress: 56.910000000000004/107.55555534362793 = 52.9% done in 4.0s, 3.6s to go
# on time step 5691 (time=56.91), 0.000702942 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 107.56 (10756 timesteps)
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000757933 s
# Working in 2D dimensions.
# Computational cell is 6.18 x 22 x 0 with resolution 50
#      block, center = (-1.585,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (4,4,4)
#      block, center = (4.16334e-17,-9.8,0)
#           size (0.17,0.34,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-9.4,0)
#           size (0.17,0.34,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-9,0)
#           size (0.17,0.34,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-8.6,0)
#           size (0.17,0.34,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-8.2,0)
#           size (0.17,0.34,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-7.8,0)
#           size (0.17,0.34,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-7.4,0)
#           size (0.17,0.34,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-7,0)
#           size (0.17,0.34,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-6.6,0)
#           size (0.17,0.34,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 41 objects not shown)...
# time for set_epsilon = 0.239299 s
# lorentzian susceptibility: frequency=10.7433, gamma=1.78571
# lorentzian susceptibility: frequency=3.47141, gamma=2.01155
# lorentzian susceptibility: frequency=2.39466, gamma=0.701702
# lorentzian susceptibility: frequency=0.66944, gamma=0.278261
# lorentzian susceptibility: frequency=0.33472, gamma=0.19438
# drude susceptibility: frequency=1e-10, gamma=0.0427474
# -----------
# Meep progress: 6.43/107.55555534362793 = 6.0% done in 4.0s, 63.0s to go
# on time step 643 (time=6.43), 0.0062281 s/step
# Meep progress: 12.9/107.55555534362793 = 12.0% done in 8.0s, 58.7s to go
# on time step 1290 (time=12.9), 0.00618438 s/step
# Meep progress: 19.32/107.55555534362793 = 18.0% done in 12.0s, 54.8s to go
# on time step 1932 (time=19.32), 0.00623402 s/step
# Meep progress: 25.810000000000002/107.55555534362793 = 24.0% done in 16.0s, 50.7s to go
# on time step 2581 (time=25.81), 0.00616812 s/step
# Meep progress: 32.22/107.55555534362793 = 30.0% done in 20.0s, 46.8s to go
# on time step 3222 (time=32.22), 0.00625017 s/step
# Meep progress: 38.37/107.55555534362793 = 35.7% done in 24.0s, 43.3s to go
# on time step 3838 (time=38.38), 0.00650497 s/step
# Meep progress: 44.31/107.55555534362793 = 41.2% done in 28.0s, 40.0s to go
# on time step 4432 (time=44.32), 0.00673901 s/step
# Meep progress: 50.69/107.55555534362793 = 47.1% done in 32.0s, 35.9s to go
# on time step 5070 (time=50.7), 0.00627728 s/step
# Meep progress: 56.230000000000004/107.55555534362793 = 52.3% done in 36.0s, 32.9s to go
# on time step 5624 (time=56.24), 0.0072226 s/step
# Meep progress: 61.31/107.55555534362793 = 57.0% done in 40.0s, 30.2s to go
# on time step 6132 (time=61.32), 0.00789126 s/step
# Meep progress: 65.79/107.55555534362793 = 61.2% done in 44.0s, 28.0s to go
# on time step 6580 (time=65.8), 0.00893905 s/step
# Meep progress: 71.43/107.55555534362793 = 66.4% done in 48.0s, 24.3s to go
# on time step 7145 (time=71.45), 0.00708604 s/step
# Meep progress: 77.54/107.55555534362793 = 72.1% done in 52.0s, 20.1s to go
# on time step 7756 (time=77.56), 0.00655452 s/step
# Meep progress: 83.95/107.55555534362793 = 78.1% done in 56.0s, 15.8s to go
# on time step 8397 (time=83.97), 0.00624049 s/step
# Meep progress: 90.23/107.55555534362793 = 83.9% done in 60.1s, 11.5s to go
# on time step 9025 (time=90.25), 0.00637211 s/step
# Meep progress: 96.69/107.55555534362793 = 89.9% done in 64.1s, 7.2s to go
# on time step 9671 (time=96.71), 0.00619996 s/step
# Meep progress: 103.05/107.55555534362793 = 95.8% done in 68.1s, 3.0s to go
# on time step 10307 (time=103.07), 0.00629087 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 107.56 (10756 timesteps)
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000406981 s
# Working in 2D dimensions.
# Computational cell is 6.18 x 22 x 0 with resolution 50
#      block, center = (-1.585,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (4,4,4)
# time for set_epsilon = 0.183024 s
# -----------
# Meep progress: 54.56/107.55555534362793 = 50.7% done in 4.0s, 3.9s to go
# on time step 5456 (time=54.56), 0.000733273 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 107.56 (10756 timesteps)
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000457048 s
# Working in 2D dimensions.
# Computational cell is 6.18 x 22 x 0 with resolution 50
#      block, center = (-1.585,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (4,4,4)
#      block, center = (4.16334e-17,-9.75,0)
#           size (0.17,0.44,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-9.25,0)
#           size (0.17,0.44,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-8.75,0)
#           size (0.17,0.44,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-8.25,0)
#           size (0.17,0.44,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-7.75,0)
#           size (0.17,0.44,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-7.25,0)
#           size (0.17,0.44,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-6.75,0)
#           size (0.17,0.44,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-6.25,0)
#           size (0.17,0.44,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-5.75,0)
#           size (0.17,0.44,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 31 objects not shown)...
# time for set_epsilon = 0.235044 s
# lorentzian susceptibility: frequency=10.7433, gamma=1.78571
# lorentzian susceptibility: frequency=3.47141, gamma=2.01155
# lorentzian susceptibility: frequency=2.39466, gamma=0.701702
# lorentzian susceptibility: frequency=0.66944, gamma=0.278261
# lorentzian susceptibility: frequency=0.33472, gamma=0.19438
# drude susceptibility: frequency=1e-10, gamma=0.0427474
# -----------
# Meep progress: 6.0/107.55555534362793 = 5.6% done in 4.0s, 67.7s to go
# on time step 600 (time=6), 0.00666869 s/step
# Meep progress: 11.38/107.55555534362793 = 10.6% done in 8.0s, 67.6s to go
# on time step 1138 (time=11.38), 0.00744107 s/step
# Meep progress: 17.330000000000002/107.55555534362793 = 16.1% done in 12.0s, 62.5s to go
# on time step 1734 (time=17.34), 0.00672057 s/step
# Meep progress: 22.990000000000002/107.55555534362793 = 21.4% done in 16.0s, 58.9s to go
# on time step 2300 (time=23), 0.00707732 s/step
# Meep progress: 28.38/107.55555534362793 = 26.4% done in 20.0s, 55.8s to go
# on time step 2839 (time=28.39), 0.00742841 s/step
# Meep progress: 34.79/107.55555534362793 = 32.3% done in 24.0s, 50.2s to go
# on time step 3480 (time=34.8), 0.00624446 s/step
# Meep progress: 41.25/107.55555534362793 = 38.4% done in 28.0s, 45.0s to go
# on time step 4126 (time=41.26), 0.00619774 s/step
# Meep progress: 47.65/107.55555534362793 = 44.3% done in 32.0s, 40.3s to go
# on time step 4766 (time=47.66), 0.00625838 s/step
# Meep progress: 54.09/107.55555534362793 = 50.3% done in 36.0s, 35.6s to go
# on time step 5410 (time=54.1), 0.00621715 s/step
# Meep progress: 60.49/107.55555534362793 = 56.2% done in 40.0s, 31.1s to go
# on time step 6050 (time=60.5), 0.00625128 s/step
# Meep progress: 66.91/107.55555534362793 = 62.2% done in 44.0s, 26.8s to go
# on time step 6692 (time=66.92), 0.00623543 s/step
# Meep progress: 73.32000000000001/107.55555534362793 = 68.2% done in 48.0s, 22.4s to go
# on time step 7333 (time=73.33), 0.00624484 s/step
# Meep progress: 79.67/107.55555534362793 = 74.1% done in 52.0s, 18.2s to go
# on time step 7968 (time=79.68), 0.00630345 s/step
# Meep progress: 86.13/107.55555534362793 = 80.1% done in 56.0s, 13.9s to go
# on time step 8614 (time=86.14), 0.00619392 s/step
# Meep progress: 92.62/107.55555534362793 = 86.1% done in 60.0s, 9.7s to go
# on time step 9263 (time=92.63), 0.00616744 s/step
# Meep progress: 99.02/107.55555534362793 = 92.1% done in 64.0s, 5.5s to go
# on time step 9903 (time=99.03), 0.00625151 s/step
# Meep progress: 104.3/107.55555534362793 = 97.0% done in 68.1s, 2.1s to go
# on time step 10431 (time=104.31), 0.0075783 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 107.56 (10756 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000571966 s
# Working in 2D dimensions.
# Computational cell is 6.18 x 22.3 x 0 with resolution 50
#      block, center = (-1.585,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (4,4,4)
# time for set_epsilon = 0.183031 s
# -----------
# Meep progress: 58.08/107.55555534362793 = 54.0% done in 4.0s, 3.4s to go
# on time step 5808 (time=58.08), 0.000688775 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 107.56 (10756 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00062108 s
# Working in 2D dimensions.
# Computational cell is 6.18 x 22.3 x 0 with resolution 50
#      block, center = (-1.585,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (4,4,4)
#      block, center = (4.16334e-17,-9.8,0)
#           size (0.17,0.64,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-9.1,0)
#           size (0.17,0.64,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-8.4,0)
#           size (0.17,0.64,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-7.7,0)
#           size (0.17,0.64,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-7,0)
#           size (0.17,0.64,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-6.3,0)
#           size (0.17,0.64,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-5.6,0)
#           size (0.17,0.64,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-4.9,0)
#           size (0.17,0.64,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-4.2,0)
#           size (0.17,0.64,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 20 objects not shown)...
# time for set_epsilon = 0.238349 s
# lorentzian susceptibility: frequency=10.7433, gamma=1.78571
# lorentzian susceptibility: frequency=3.47141, gamma=2.01155
# lorentzian susceptibility: frequency=2.39466, gamma=0.701702
# lorentzian susceptibility: frequency=0.66944, gamma=0.278261
# lorentzian susceptibility: frequency=0.33472, gamma=0.19438
# drude susceptibility: frequency=1e-10, gamma=0.0427474
# -----------
# Meep progress: 5.83/107.55555534362793 = 5.4% done in 4.0s, 69.9s to go
# on time step 583 (time=5.83), 0.00686899 s/step
# Meep progress: 11.290000000000001/107.55555534362793 = 10.5% done in 8.0s, 68.3s to go
# on time step 1130 (time=11.3), 0.00732555 s/step
# Meep progress: 17.14/107.55555534362793 = 15.9% done in 12.0s, 63.3s to go
# on time step 1715 (time=17.15), 0.00684225 s/step
# Meep progress: 23.080000000000002/107.55555534362793 = 21.5% done in 16.0s, 58.6s to go
# on time step 2310 (time=23.1), 0.00673274 s/step
# Meep progress: 29.47/107.55555534362793 = 27.4% done in 20.0s, 53.0s to go
# on time step 2949 (time=29.49), 0.0062656 s/step
# Meep progress: 35.85/107.55555534362793 = 33.3% done in 24.0s, 48.0s to go
# on time step 3587 (time=35.87), 0.00627277 s/step
# Meep progress: 42.15/107.55555534362793 = 39.2% done in 28.0s, 43.5s to go
# on time step 4217 (time=42.17), 0.00635054 s/step
# Meep progress: 48.410000000000004/107.55555534362793 = 45.0% done in 32.0s, 39.1s to go
# on time step 4842 (time=48.42), 0.00640555 s/step
# Meep progress: 54.2/107.55555534362793 = 50.4% done in 36.0s, 35.5s to go
# on time step 5421 (time=54.21), 0.00691143 s/step
# Meep progress: 60.52/107.55555534362793 = 56.3% done in 40.0s, 31.1s to go
# on time step 6053 (time=60.53), 0.00633832 s/step
# Meep progress: 66.87/107.55555534362793 = 62.2% done in 44.0s, 26.8s to go
# on time step 6688 (time=66.88), 0.00630384 s/step
# Meep progress: 73.14/107.55555534362793 = 68.0% done in 48.0s, 22.6s to go
# on time step 7315 (time=73.15), 0.00638081 s/step
# Meep progress: 79.47/107.55555534362793 = 73.9% done in 52.0s, 18.4s to go
# on time step 7948 (time=79.48), 0.00632002 s/step
# Meep progress: 85.71000000000001/107.55555534362793 = 79.7% done in 56.0s, 14.3s to go
# on time step 8572 (time=85.72), 0.0064176 s/step
# Meep progress: 91.98/107.55555534362793 = 85.5% done in 60.1s, 10.2s to go
# on time step 9199 (time=91.99), 0.00638714 s/step
# Meep progress: 98.15/107.55555534362793 = 91.3% done in 64.1s, 6.1s to go
# on time step 9816 (time=98.16), 0.00648559 s/step
# Meep progress: 104.52/107.55555534362793 = 97.2% done in 68.1s, 2.0s to go
# on time step 10453 (time=104.53), 0.00628117 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 107.56 (10756 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000581026 s
# Working in 2D dimensions.
# Computational cell is 6.18 x 22.7 x 0 with resolution 50
#      block, center = (-1.585,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (4,4,4)
# time for set_epsilon = 0.189285 s
# -----------
# Meep progress: 52.49/107.55555534362793 = 48.8% done in 4.0s, 4.2s to go
# on time step 5249 (time=52.49), 0.000762163 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 107.56 (10756 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000634909 s
# Working in 2D dimensions.
# Computational cell is 6.18 x 22.7 x 0 with resolution 50
#      block, center = (-1.585,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (4,4,4)
#      block, center = (4.16334e-17,-9.9,0)
#           size (0.17,0.84,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-9,0)
#           size (0.17,0.84,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-8.1,0)
#           size (0.17,0.84,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-7.2,0)
#           size (0.17,0.84,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-6.3,0)
#           size (0.17,0.84,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-5.4,0)
#           size (0.17,0.84,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-4.5,0)
#           size (0.17,0.84,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-3.6,0)
#           size (0.17,0.84,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.16334e-17,-2.7,0)
#           size (0.17,0.84,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 14 objects not shown)...
# time for set_epsilon = 0.226872 s
# lorentzian susceptibility: frequency=10.7433, gamma=1.78571
# lorentzian susceptibility: frequency=3.47141, gamma=2.01155
# lorentzian susceptibility: frequency=2.39466, gamma=0.701702
# lorentzian susceptibility: frequency=0.66944, gamma=0.278261
# lorentzian susceptibility: frequency=0.33472, gamma=0.19438
# drude susceptibility: frequency=1e-10, gamma=0.0427474
# -----------
# Meep progress: 6.05/107.55555534362793 = 5.6% done in 4.0s, 67.1s to go
# on time step 605 (time=6.05), 0.00661267 s/step
# Meep progress: 11.98/107.55555534362793 = 11.1% done in 8.0s, 64.0s to go
# on time step 1198 (time=11.98), 0.00677841 s/step
# Meep progress: 15.96/107.55555534362793 = 14.8% done in 12.0s, 69.0s to go
# on time step 1596 (time=15.96), 0.0100506 s/step
# Meep progress: 20.04/107.55555534362793 = 18.6% done in 16.0s, 70.0s to go
# on time step 2004 (time=20.04), 0.00980615 s/step
# Meep progress: 24.92/107.55555534362793 = 23.2% done in 20.0s, 66.4s to go
# on time step 2493 (time=24.93), 0.00819321 s/step
# Meep progress: 30.39/107.55555534362793 = 28.3% done in 24.0s, 61.0s to go
# on time step 3040 (time=30.4), 0.00731489 s/step
# Meep progress: 36.33/107.55555534362793 = 33.8% done in 28.0s, 55.0s to go
# on time step 3633 (time=36.33), 0.00674612 s/step
# Meep progress: 42.32/107.55555534362793 = 39.3% done in 32.0s, 49.4s to go
# on time step 4232 (time=42.32), 0.00668763 s/step
# Meep progress: 48.160000000000004/107.55555534362793 = 44.8% done in 36.0s, 44.5s to go
# on time step 4816 (time=48.16), 0.00686503 s/step
# Meep progress: 54.160000000000004/107.55555534362793 = 50.4% done in 40.1s, 39.5s to go
# on time step 5416 (time=54.16), 0.00667272 s/step
# Meep progress: 58.32/107.55555534362793 = 54.2% done in 44.1s, 37.2s to go
# on time step 5832 (time=58.32), 0.0096405 s/step
# Meep progress: 61.4/107.55555534362793 = 57.1% done in 48.1s, 36.1s to go
# on time step 6140 (time=61.4), 0.0130066 s/step
# Meep progress: 65.61/107.55555534362793 = 61.0% done in 52.1s, 33.3s to go
# on time step 6561 (time=65.61), 0.00951267 s/step
# Meep progress: 71.66/107.55555534362793 = 66.6% done in 56.1s, 28.1s to go
# on time step 7166 (time=71.66), 0.00661938 s/step
# Meep progress: 77.71000000000001/107.55555534362793 = 72.3% done in 60.1s, 23.1s to go
# on time step 7771 (time=77.71), 0.00661984 s/step
# Meep progress: 83.31/107.55555534362793 = 77.5% done in 64.1s, 18.7s to go
# on time step 8331 (time=83.31), 0.00717561 s/step
# Meep progress: 87.26/107.55555534362793 = 81.1% done in 68.1s, 15.8s to go
# on time step 8726 (time=87.26), 0.0101292 s/step
# Meep progress: 92.26/107.55555534362793 = 85.8% done in 72.1s, 12.0s to go
# on time step 9226 (time=92.26), 0.00802728 s/step
# Meep progress: 97.46000000000001/107.55555534362793 = 90.6% done in 76.1s, 7.9s to go
# on time step 9746 (time=97.46), 0.00769349 s/step
# Meep progress: 102.39/107.55555534362793 = 95.2% done in 80.1s, 4.0s to go
# on time step 10239 (time=102.39), 0.00812597 s/step
# Meep progress: 106.72/107.55555534362793 = 99.2% done in 84.1s, 0.7s to go
# on time step 10672 (time=106.72), 0.00924439 s/step
# run 0 finished at t = 107.56 (10756 timesteps)
